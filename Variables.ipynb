# %%
#variables
name="vandana"
print(name)
# Out:
# vandana

# %%
age=20
print(age)
# Out:
# 20

# %%
city="angallu"
print(city)
# Out:
# angallu

# %%
college="mtiet"
print(college)
# Out:
# mtiet

# %%
color="blue"
print(color)
# Out:
# blue

# %%
name="vandana"
age=20
city="angallu"
print(name)
print(age)
print(city)
# Out:
# vandana
# 20
# angallu

# %%
marks= 450
print(marks)
# Out:
# 450

# %%
price = 99.99
print(price)
# Out:
# 99.99

# %%
score=70
print(score)
score=95
print(score)
# Out:
# 70
# 95

# %%
dream_job="web developer"
print(dream_job)
# Out:
# web developer

# %%
name="this is vandana"
educaton = "i am studing btech"
hobby = "i love coding"
intrest = "i have intrested in web development"
sleeping ="yes"
print("name:",a)
print("education:",b)
print("hobby:",c)
print("intrest:",d)
print("sleeping:",e)
# Out:
# name: this is vandana
# education: i am studing btech
# hobby: i love coding
# intrest: i have intrested in web development
# sleeping: yes

# %%
name="this is vandana"
educaton = "i am studing btech"
hobby = "i love coding"
intrest = "i have intrested in web development"
sleeping ="yes"
print(a,b,c,d,e)
# Out:
# this is vandana i am studing btech i love coding i have intrested in web development yes

# %%
name = "vandana"
Age = 20
college = "mtiet"
branch="Cse" 
goal = "web developer"
print("Name:",name)
print("Age:",age)
print("College:",college)
print("Branch:",branch)
print("Goal:",goal)
# Out:
# Name: vandana
# Age: 20
# College: mtiet
# Branch: Cse
# Goal: web developer

# %%
name = "vandana"
age = 20
course ="btech"
college = "mtiet"
branch="Cse" 
year=2026
cgpa=7.5
skills="python, react, django"
print("Name:",name)
print("Age:",age)
print("course:",course)
print("College:",college)
print("Branch:",branch)
print("year:",year)
print("cgpa:",cgpa)
print("skills:",skills)
# Out:
# Name: vandana
# Age: 20
# course: btech
# College: mtiet
# Branch: Cse
# year: 2026
# cgpa: 7.5
# skills: python, react, django

# %%
employee_name="vandy"
basic_salary=45000
bonus=5
tax=150
print("employee_name:",employee_name)
print("basic_salary:",basic_salary)
print("bonus:",bonus)
print("tax:",tax)
# Out:
# employee_name: vandy
# basic_salary: 45000
# bonus: 5
# tax: 150

# %%
a=100
b=200
a,b = b,a

# %%
#2 
length=15
breadth=10
area=length*breadth
perimeter=2*(length+breadth)
print("length:",length)
print("breadth:",breadth)
print("area:",area)
print("perimeter:",perimeter)
# Out:
# length: 15
# breadth: 10
# area: 150
# perimeter: 50

# %%
lenth=25
breadth=50
area=length*breadth
perimeter=2*(length+breadth)
print("area:",area)
print("perimeter:",perimeter)
# Out:
# area: 750
# perimeter: 130
