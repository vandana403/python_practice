# %%
#Arithmetic Operators
print(15 + 5)
print(20 - 8)
print(9 * 6)
print(20 / 4)
print(20 // 4)
print(20 % 3)
print(3 ** 4)
# Out:
# 20
# 12
# 54
# 5.0
# 5
# 2
# 81

# %%
num1 = int(input("enter your first number:"))
num2 = int(input("enter your second number:"))

sum= num1 + num2
Difference = num1 - num2
product = num1 * num2
division = num1 / num2
floor_division = num1 // num2
remainder = num1 % num2

print("Sum:", sum)
print("Difference :", Difference)
print("Product:", product)
print("Division:", division)
print("floor_division:", floor_division)
print("remainder :",remainder)
# Out:
# Sum: 57
# Difference : -11
# Product: 782
# Division: 0.6764705882352942
# floor_division: 0
# remainder : 23

# %%
num = int(input("enter your first number:"))
square = num ** 2
print("square:",square)
# Out:
# square: 25

# %%
num = int (input("enter your number:"))
cube =  num * num * num
print("cube:",cube)
# Out:
# cube: 27

# %%
a = 25
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 29
# 21
# 100
# 6.25
# 6
# 1
# 390625

# %%
number1 = int(input("enter your first number:"))
number2 = int(input("enter your second number:"))

addition = number1 + number2
subtraction = number1 - number2
multiplication = number1 * number2
division = number1 / number2
floor_division = number1 // number2
remainder = number1 % number2
power = number1 ** number2

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", number1 // number2)
print("Remainder:", number1 % number2)
print("Power:", number1 ** number2)
# Out:
# Addition: 79
# Subtraction: -11
# Multiplication: 1530
# Division: 0.7555555555555555
# Floor Division: 0
# Remainder: 34
# Power: 825184889837725994971915471173621692744697928074424045623011467853824

# %%
#Comparison Operators
print(10 == 10)
# Out:
# True

# %%
print(15 != 20)
# Out:
# True

# %%
print(8 > 12)
# Out:
# False

# %%
print(25 < 30)
# Out:
# True

# %%
print(20 >= 20)
# Out:
# True

# %%
print(15 <= 10)
# Out:
# False

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a < b)
print(a > b)
# Out:
# False
# True
# True
# False

# %%
print("Hello" == "Hello")
# Out:
# True

# %%
print("vandana is learning py" == "vandana is learning py")
# Out:
# True

# %%
num1 = int(input("enter your first number:"))
num2 = int(input("enter your second number:"))
print(num1 == num2)
print(num1 > num2)
print(num1 < num2)
# Out:
# False
# True
# False

# %%
x = 15
y = 15

print(x >= y)
print(x <= y)
print(x != y)
# Out:
# True
# True
# False

# %%
print(5 == "5")
# Out:
# False

# %%
marks = int(input("enter your marks:"))
pass_marks= int(input("enter your pass marks:"))
print("marks:",marks)
print("pass_marks:", pass_marks)
print(marks > pass_marks)
# Out:
# marks: 56
# pass_marks: 35
# True

# %%
marks = 50
pass_marks = 35

print(marks == pass_marks)
print(marks != pass_marks)
print(marks >= pass_marks)
print(marks <= pass_marks)
# Out:
# False
# True
# True
# False

# %%
#Logical Operators (TRUE OR FALSE)----> (and or not)-->types.
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(False or True)
# Out:
# True

# %%
print(False or False)
# Out:
# False

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %%
age = 20
print(age >= 18 and age <= 25)
# Out:
# True

# %%
marks = 45
print(marks >= 35 and marks <= 100)
# Out:
# True

# %%
number = 10
print(number > 5 or number < 0)
# Out:
# True
