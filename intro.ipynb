# %%
print("helo world")
# Out:
# helo world

# %%
print("vandana")
print("i am learning python")
# Out:
# vandana
# i am learning python

# %%
print("mtiet")
# Out:
# mtiet

# %%
print("I am learning Python")
print("Python is easy")
print("I will become a developer")
# Out:
# I am learning Python
# Python is easy
# I will become a developer

# %%
name=input("enter your name:")
age=input("enter your age:")
course=input("enter your course:")
language=input("enter your language:")
print("name:",name)
print("age:",age)
print("course:",course)
print("language:",language)
# Out:
# name: vandy
# age: 18
# course: btech
# language: python

# %%
#variables
name="vandana"
print(name)
# Out:
# vandana

# %%
city_name="mpl"
print(city_name)
# Out:
# mpl

# %%
age=18
college="sv college"
print(age)
print(college)
# Out:
# 18
# sv college

# %%
language="Python"
print(f" i am learning, {language}.")
print("I am learning", language)
# Out:
#  i am learning, Python.
# I am learning Python

# %%
favourite_color="blue"
print(favourite_color)
# Out:
# blue

# %%
x=5
y=10
print(x)
print(y)
# Out:
# 5
# 10

# %%
price=550
price=750
print(price)
# Out:
# 750

# %%
name= "navya"
age=87
city="mpl"
print(name)
print(age)
print(city)
# Out:
# navya
# 87
# mpl

# %%
Book_name="harry potter"
Author="novel"
Price=550
print(Book_name)
print(Author)
print(Price)
# Out:
# harry potter
# novel
# 550

# %%
a= 10
print(a)
a=20
print(a)
# Out:
# 10
# 20

# %%
name="vandy"
age=28
college="mtiet"
course="btech"
dream_job="software"
print(name)
print(age)
print(college)
print(course)
print(dream_job)
# Out:
# vandy
# 28
# mtiet
# btech
# software

# %%
value=10  # 10 is a integer
print(value)
value="hello"  #string
print(value)
value="True"  #bool
print(value)
value=34.5
print(value)  #float
# Out:
# 10
# hello
# True
# 34.5

# %%
name=input("enter your name:")
age=input("enter your age:")
college=input("enter your college:")
course=input("enter your course:")
city =input("enter your city:")
print("name:",name)
print("age:",age)
print("college:",college)
print("course:",course)
print("city:",city)
# Out:
# name: vandy
# age: 19
# college: mtiet
# course: btech
# city: mpl

# %%
a=45
b=a
a=10
print(a)
print(b)
# Out:
# 10
# 45
