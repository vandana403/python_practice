# %%
print("Hello World")
# Out:
# Hello World

# %%
1.#variables and input output prectice questions
name="vandana"
print(name)
# Out:
# vandana

# %%
#2
age=45
print(age)
# Out:
# 45

# %%
#3
city="mpl"
college="sv college"
course="btech"
print(city)
print(college)
print(course)
# Out:
# mpl
# sv college
# btech

# %%
#4
name=input("enter your name:")
print(name)
# Out:
# vandana

# %%
#5
color=input("enter your favourite color:")
print(color)
# Out:
# blue

# %%
#6
a=input("enter your age:")
print(f"you are {a} years old")# f is  formatted message means look inside{}and replace them with the value of the variable
# Out:
# you are 23 years old

# %%
#7
name=input("enter your name:")
age=input("enter your age:")
print("name:",name)
print("age:",age)
# Out:
# name: vandy
# age: 20

# %%
#8
college=input("enter your college:")
branch=input("enter your branch:")
print("college:",college)
print("branch:",branch)
# Out:
# college: mtiet
# branch: cse

# %%
#9
name=input("enter your name:")
print(f"hello, { name}")
# Out:
# hello, lava

# %%
#10
name=input("enter your name:")
age=input("enter your age:")
print(f"Hello, {name} you are {age} years old.")
# Out:
# Hello, lava you are 21 years old.

# %%
#11
name=input("enter your name:")
city=input("enter your city:")
print(f"hello,{name} welcome to {city}.")
# Out:
# hello,vandy welcome to mpl.

# %%
#12
name=input("enter your name:")
age=input("enter your age:")
print(f"Hello, {name} you are {age} years old.")
# Out:
# Hello, vandy you are 45 years old.

# %%
#13
name=input("enter your name:")
age=input("enter your age:")
city=input("enter your city:")
print(f"hello,{name}!")
print(f"you are {age} years old.")
print(f"you are living in {city}.")
# Out:
# hello,shailu!
# you are 18 years old.
# you are living in angallu.

# %%
#14
name=input("enter your name:")
college=input("enter your college:")
branch=input("enter your branch:")
print(f"hi {name} my college name is {college} and my branch is {branch}.")
# Out:
# hi vandy my college name is sv and my branch is cse.

# %%
#15
a="vandana"
print(f"my name is {a}!")
# Out:
# my name is vandana!

# %%
#16
num1=input("enter no:")
num2=input("enter no")
print(num1+num2)
# Out:
# 2222

# %%
#17
firstname="vandana"
lastname="vandy"
print(firstname+lastname)
# Out:
# vandanavandy

# %%
#18
a=input("enter your school:")
b=input("enter your class:")
print(f"my school name is {a}. i am studying {b}.")
# Out:
# my school name is sv. i am studying 3rd.

# %%
#19
a=input("enter your country:")
b=input("enter your state:")
print(f"my country is {a} and my state is {b}")
# Out:
# my country is ap and my state isdelhi

# %%
#20
a=input("enter your favourite movie:")
b=input("enter your favourite actor:")
c=input("enter your favourite language:")
print(a,b,c)
# Out:
# hzhvf mnvudzhk nmzkudj

# %%
#data types
#21
age = 24
print(age)
# Out:
# 24

# %%
#22
height= 4.5 
print(height)
# Out:
# 4.5

# %%
#23
name="navya"
print("name:",name)
# Out:
# name: navya

# %%
#24
is_student1=True
is_student2=False
print(is_student2)
# Out:
# False

# %%
#25
age= 20
height= 5.5
name= "vandana"
is_student=False
print(age)
print(height)
print (name)
print(is_student)
# Out:
# 20
# 5.5
# vandana
# False

# %%
#26
age = 20
print(type(age))
# Out:
# <class 'int'>

# %%
#27
name="vandana"
print(type(name))
# Out:
# <class 'str'>

# %%
#28
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#29
numbers=(10,20,30)
print(numbers)
# Out:
# (10, 20, 30)

# %%
#30
student={
    "name":"vandana",
    "age" : 20
}
print(student)
# Out:
# {'name': 'vandana', 'age': 20}

# %%
#11
a= 23
b=4.5
c="vandana"
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#
numbers=[1,2,3,4,5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#
colors=("blue","pink","yellow","black")
print(colors)
# Out:
# ('blue', 'pink', 'yellow', 'black')

# %%
#
student= {
    "city":"mpl",
    "college":"mtiet",
    "course":"btech"
}
print(student)
# Out:
# {'city': 'mpl', 'college': 'mtiet', 'course': 'btech'}

# %%
#
a=100
b=25.5
c='python'
d=True
e=[1,2,3]
f=(4,5)
g={'a':1}
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
#opetators
#arithmetic operations
a=25
b=15
print(a+b)
# Out:
# 40

# %%
#
a=12
b=40
print(a-b)
# Out:
# -28

# %%
#
a=8
b=9
print(a*b)
# Out:
# 72

# %%
#
a=50
b=5
print(a/b)
# Out:
# 10.0

# %%
#
a=17
b=4
print(a%b)
# Out:
# 1

# %%
#
a=25
b=4
print(a//b)
# Out:
# 6

# %%
#
a=3
b=4
print(a**b)
# Out:
# 81

# %%
#
a=20
b=6
print(a+b)        # / gives entire value with decimal 
print(a-b)       #Gives the exact answer. Keeps the decimal part  #(even if it is .0).
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)  
                    #// gives only  Gives only the whole number
                    #  #Removes the decimal part
# Out:
# 26
# 14
# 120
# 3.3333333333333335
# 2
# 3
# 64000000

# %%
#comparision operations
a=10
b=5
print(a>b)
# Out:
# True

# %%
a=10
b=5
print(a<b)
# Out:
# False

# %%
a=10
b=5
print(a>=b)
# Out:
# True

# %%
a=10
b=5
print(a<=b)
# Out:
# False

# %%
a=10
b=5
print(a==b)
# Out:
# False

# %%
a=10
b=5
print(a!=b)
# Out:
# True

# %%
#assignment operations
